# %% [markdown]
# <a href="https://colab.research.google.com/github/ForestHouse2316/Imdaejuteck/blob/main/%EC%9D%B8%EA%B5%AC%ED%86%B5%EA%B3%84_%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  
  path = '/content/drive/MyDrive/Colab Notebooks/인구통계.csv'

# %%
import pandas as pd
import glob

filename = glob.glob(path)[0]
filename
# Out:
# '/content/drive/MyDrive/Colab Notebooks/인구통계.csv'

# %%
df = pd.read_csv(filename, encoding='cp949', index_col='행정구역')
df.head()
# Out:
#                             2019년12월_계_총인구수  ... 2019년12월_계_100세 이상
# 행정구역                                         ...
# 서울특별시  (1100000000)               9,729,107  ...              6,244
# 서울특별시 종로구 (1111000000)              151,290  ...                253
# 서울특별시 종로구 청운효자동(1111051500)          12,734  ...                 17
# 서울특별시 종로구 사직동(1111053000)             9,535  ...                 19
# 서울특별시 종로구 삼청동(1111054000)             2,758  ...                  8
#
# [5 rows x 103 columns]

# %%
df.shape
# Out:
# (3821, 103)

# %%
df.columns = df.columns.str.replace('2019년12월_계_','')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3821 entries, 서울특별시  (1100000000) to 제주특별자치도 서귀포시 예래동(5013062000)
# Columns: 103 entries, 총인구수 to 100세 이상
# dtypes: int64(1), object(102)
# memory usage: 3.0+ MB

# %%
df['0세'].dtype=='object'
# Out:
# True

# %%
for col in df.columns:
  if df[col].dtype == 'object':
    df[col] = df[col].str.replace(',','')

# %%
df=df.astype(float)
df.head()
# Out:
#                                   총인구수    연령구간인구수  ...    99세  100세 이상
# 행정구역                                               ...
# 서울특별시  (1100000000)          9729107.0  9729107.0  ...  977.0   6244.0
# 서울특별시 종로구 (1111000000)        151290.0   151290.0  ...   36.0    253.0
# 서울특별시 종로구 청운효자동(1111051500)    12734.0    12734.0  ...    3.0     17.0
# 서울특별시 종로구 사직동(1111053000)       9535.0     9535.0  ...    4.0     19.0
# 서울특별시 종로구 삼청동(1111054000)       2758.0     2758.0  ...    0.0      8.0
#
# [5 rows x 103 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3821 entries, 서울특별시  (1100000000) to 제주특별자치도 서귀포시 예래동(5013062000)
# Columns: 103 entries, 총인구수 to 100세 이상
# dtypes: float64(103)
# memory usage: 3.0+ MB

# %%
df['10세'].describe()
# Out:
# count      3821.000000
# mean        374.396493
# std        2697.723732
# min           0.000000
# 25%          16.000000
# 50%          78.000000
# 75%         210.000000
# max      126910.000000
# Name: 10세, dtype: float64

# %%
df.index.str.contains('텍스트')
# Out:
# array([False, False, False, ..., False, False, False])

# %%
mask = df.index.str.contains('평촌')
city = df[mask]
city
# Out:
#                                 총인구수  연령구간인구수     0세  ...  98세  99세  100세 이상
# 행정구역                                                  ...
# 경기도 안양시 동안구 평촌동(4117357000)  15702.0  15702.0  101.0  ...  0.0  2.0      4.0
#
# [1 rows x 103 columns]

# %%
city = city.iloc[:,2:]
city
# Out:
#                                 0세    1세     2세     3세  ...  97세  98세  99세  100세 이상
# 행정구역                                                    ...
# 경기도 안양시 동안구 평촌동(4117357000)  101.0  90.0  115.0  125.0  ...  0.0  0.0  2.0      4.0
#
# [1 rows x 101 columns]

# %%
city.T
# Out:
# 행정구역     경기도 안양시 동안구 평촌동(4117357000)
# 0세                             101.0
# 1세                              90.0
# 2세                             115.0
# 3세                             125.0
# 4세                             182.0
# ...                              ...
# 96세                              0.0
# 97세                              0.0
# 98세                              0.0
# 99세                              2.0
# 100세 이상                          4.0
#
# [101 rows x 1 columns]

# %%
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq
import matplotlib.pyplot as plt
plt.rcParams['font.family']="Nanum Gothic"
plt.rcParams['axes.unicode_minus']=False
# %matplotlib inline

plt.style.use('ggplot')
city.T.plot()
plt.title('')
plt.show()
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 160690 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-6_all.deb ...
# Unpacking fonts-nanum-eco (1.000-6) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20170925-1_all.deb ...
# Unpacking fonts-nanum-extra (20170925-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-1_all.deb ...
# Unpacking fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-extra (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Setting up fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-eco (1.000-6) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# ...

# %%
cityname=input("=>")
mask = df.index.str.contains(cityname)
city=df[mask]
city=city.iloc[:,2:]
city.T
plt.style.use('ggplot')
city.T.plot(kind='area',stacked=False,alpha=0.2,figsize=(10,6))
plt.show()
# Out:
# =>송도
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
df = df.div(df['총인구수'],axis=0)
df.head()
# Out:
#                              총인구수  연령구간인구수  ...       99세   100세 이상
# 행정구역                                        ...
# 서울특별시  (1100000000)           1.0      1.0  ...  0.000100  0.000642
# 서울특별시 종로구 (1111000000)        1.0      1.0  ...  0.000238  0.001672
# 서울특별시 종로구 청운효자동(1111051500)   1.0      1.0  ...  0.000236  0.001335
# 서울특별시 종로구 사직동(1111053000)     1.0      1.0  ...  0.000420  0.001993
# 서울특별시 종로구 삼청동(1111054000)     1.0      1.0  ...  0.000000  0.002901
#
# [5 rows x 103 columns]

# %%
del df['총인구수'],df['연령구간인구수']

# %%
cityname=input()
mask = df.index.str.contains(cityname)
print('')
print('[검색결과')
for i in range(len(df[mask])):
  result = f'{i+1}) {df[mask].index[i]}'
  print(result)
choice = int(input('번호선택'))
city = df[mask].iloc[choice-1:choice,:]
city.T.plot(figsize=(8,6))
plt.show()
# Out:
# 1
#
# [검색결과
# 1) 서울특별시  (1100000000)
# 2) 서울특별시 종로구 (1111000000)
# 3) 서울특별시 종로구 청운효자동(1111051500)
# 4) 서울특별시 종로구 사직동(1111053000)
# 5) 서울특별시 종로구 삼청동(1111054000)
# 6) 서울특별시 종로구 부암동(1111055000)
# 7) 서울특별시 종로구 평창동(1111056000)
# 8) 서울특별시 종로구 무악동(1111057000)
# 9) 서울특별시 종로구 교남동(1111058000)
# 10) 서울특별시 종로구 가회동(1111060000)
# 11) 서울특별시 종로구 종로1.2.3.4가동(1111061500)
# 12) 서울특별시 종로구 종로5.6가동(1111063000)
# 13) 서울특별시 종로구 이화동(1111064000)
# 14) 서울특별시 종로구 혜화동(1111065000)
# 15) 서울특별시 종로구 창신제1동(1111067000)
# 16) 서울특별시 종로구 창신제2동(1111068000)
# 17) 서울특별시 종로구 창신제3동(1111069000)
# 18) 서울특별시 종로구 숭인제1동(1111070000)
# 19) 서울특별시 종로구 숭인제2동(1111071000)
# 20) 서울특별시 중구 (1114000000)
# 21) 서울특별시 중구 소공동(1114052000)
# 22) 서울특별시 중구 회현동(1114054000)
# 23) 서울특별시 중구 명동(1114055000)
# 24) 서울특별시 중구 필동(1114057000)
# 25) 서울특별시 중구 장충동(1114058000)
# 26) 서울특별시 중구 광희동(1114059000)
# 27) 서울특별시 중구 을지로동(1114060500)
# 28) 서울특별시 중구 신당동(1114061500)
# 29) 서울특별시 중구 다산동(1114062500)
# 30) 서울특별시 중구 약수동(1114063500)
# 31) 서울특별시 중구 청구동(1114064500)
# ...

# %%
cityname = input()
mask=df.index.str.contains(cityname)
city = df[mask]
# Out:
# 대치1

# %%
city.iloc[0]
type(city.iloc[0])
df_sub = df.sub.(city.iloc[0],axis=1)
df_sub.head()
# Out:
#   File "<ipython-input-57-81667e6158e7>", line 3
#     df_sub = df.sub.(city.iloc[0],axis=1)
#                     ^
# SyntaxError: invalid syntax

# %%
findcity=df_sub_sum.sort_values().index[:1]
findcity
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-e8011c5cd427> in <module>()
# ----> 1 findcity=df_sub_sum.sort_values().index[:1]
#       2 findcity
#
# TypeError: sort_values() missing 1 required positional argument: 'by'
